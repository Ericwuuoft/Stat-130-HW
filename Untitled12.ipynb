# %% [markdown]
# Analysis 1: confidence interval for Average Life satisfaction
# Research question:  Average Life Satisfaction
# Variables and Data collection
# For this analysis I will explore the wellness_ life satisfaction Variable from the CSCS dataset. This variable captures the self-reported life satisfaction level of participants, The satisfaction ranges from 1 to 10 where higher values indicate higher-level indicates a higher level of satisfaction. We will use the variables to estimate the overall average level of life with a confidence interval to understand the uncertainty around the estimated mean.
# Data visualization and Pre-assumptions
# The visualization I would use for this analysis is a histogram. A histogram could help me understand the distribution of life satisfaction scores. And will help identify if the data is normally distributed or if there is any significant deviation such as skewness or outliers.
# My pre assumption is that calculating the confidence interval is that the  sample data is approximately normally distributed, which make scenes to give the large sample size。
# Analysis Method
# For the analysis method I would calculate a 95% confidence interval for the mean life satisfaction score using the normal approximation. The formula for the confidence interval is:
# Where?
# -Sample mean of life satisfaction scores
# -sample standard deviation
# -sample size
# -critical value for a 95% confidence level.
# Expected results.
# The result will include the average life satisfaction score of people during quarantine and the 95% confidence interval. A narrower confidence interval means that we have a more precise estimate of the average life satisfaction. And a bigger interval indicates more variability.
# Content similarity: it is kind of like TUT 4 about the coffee scores.
#
# Section 2 (linear regression equations)
# Research questions the relationship between Life Satisfaction and Personality/Wellness Score
# Variable and Data connection
# In this analysis i will explore the relationship between life satisfaction and various psychological personality captured by PSYCH_big_five_inventory_ variable. These traits include agreeableness, conscientiousness, extraversion, neuroticism, and openness.
#
# The primary variable is life satisfaction score, and personality is the dependent variable.
# B) we will use the data collected from the Canadian social connection survey dataset.
#
# Data Visualization and Pre-Assumption
# To better understand the relationship between the variable I think that scatter plot will be the best fitting amongst all the other graphs, also we will include a linear trendline to visualize any potential linear relationship amongst the data.
# Pre assumptions
# We will validate the following assumptions for linear regression:
# -linearity: check if the relationship is linear or not.’
# -Normality of residuals: we will use a QQ plot and Shapiro-wilk test to test it
# -homoscedasticity- in this we will use residual vs. fitted value plots
# -Multicollinearity: calculate the VIF (variance inflation factor.)
# Analysis Method and Expected Results
# A)	We will use multiple linear regression to analyze the effect of the big Five traits on life satisfaction.
# B)	We would expect to find a positive relationship between traits like extraversion or agreeableness and life satisfaction, and negative relationship with neuroticism.
# C)	These results can help us identify rather or not that personality traits are linked to better well-being, aiding in the design of intervention to improve mental health.
#
# Analysis 3 hypothesis testing
# Variables and Data collection
# Research Question: the question I will be examing  is whether visiting family significantly affects an individual's subjective well-being?
# Data are from these two columns-
# 1.	CONNECTION_activities_visited_family_p3m and
# This variable indicates whether an individual has visited family in the past three month or not it is a categorical variable with possible response of yes or no.
# 2.	WELLNESS_subjective_hapiness_scle_always_happy
# This variable represents an individual’s subjective assessment of their happiness. It is a variable with level of agreement to statement such as strongly agree, agree, Etc.….
#
# Data Visualization and Pre-Assumption testing
# 1.	Data visualization: Bar plot will be used to represent the frequency of individual who have visited their family’s vs people who have not visited their family. And a box plot will illustrate the distribution of subjective happiness scores for each group.
#
# 2.	Pre-Assumption testing: since That hypothesis testing requires certain assumption. I will perform a normality testing on the subjective happiness variable using a sharpiro wilk test to assess if it follows or not a normal distribution.
#
# Section3
# Analysis method
# Id assumptions are met I will us an independent t-test to compare the happiness scores between the two groups.
#
# Expected results.
# Significant difference: if a significant difference is founded it suggest that visiting family positively will affect well-being however if there is not a significant difference then there is not relativeness.
#
#
#
#
#
#
#
#
# Hi, I would like to work with Jonny and Karson since we have similar topics and is easy for us to communicate.
